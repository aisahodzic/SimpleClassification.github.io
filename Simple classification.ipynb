# %% [markdown]
# ## Artificial Intelligence, Part II: Learning (continued)

# %% [markdown]
# ### Task 1. Warm up with scikit learn
#
# Using the function MLPClassifier from scikit_learn, learn a neural network on each of the dataset below.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier

import scipy.io
class1 = scipy.io.loadmat('MLPdata1.mat')['MLPdata1']
class2 = scipy.io.loadmat('MLPdata2.mat')['MLPdata2']


plt.scatter(class1[:,0],class1[:,1], c='r')
plt.scatter(class2[:,0],class2[:,1], c='b')
plt.show()



from sklearn.neural_network import MLPClassifier

classifier = MLPClassifier (hidden_layer_sizes = (10,), activation = 'logistic', solver = 'lbfgs')




targetsclass1 = np.ones((np.shape(class1)[0],1))
targetsclass2 = -np.ones((np.shape(class2)[0],1))


targets = np.vstack((targetsclass1, targetsclass2))

data = np.vstack((class1,class2))

classifier.fit(data,targets)

x1min = np.min(data[:,0])
x1max = np.max(data[:,0])
x2min = np.min(data[:,1])
x2max = np.max(data[:,1])

x1GridSide = np.linspace(x1min, x1max)
x2GridSide = np.linspace(x2min, x2max)

x1grid, x2grid = np.meshgrid (x1GridSide,x2GridSide )

grid_data = np.hstack((x1grid.flatten().reshape(-1,1), x2grid.flatten().reshape(-1,1)))


predicted_targets = classifier.predict(grid_data)
# Out:
# /Users/aishahodzic/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
import scipy.io

class1 = scipy.io.loadmat('MLPdata1.mat')['MLPdata1']
class2 = scipy.io.loadmat('MLPdata2.mat')['MLPdata2']


plt.scatter(class1[:,0],class1[:,1], c='r')
plt.scatter(class2[:,0],class2[:,1], c='b')
plt.show()


from sklearn.neural_network import MLPClassifier

classifier = MLPClassifier(hidden_layer_sizes =(100,100,100), activation = 'logistic', solver='lbfgs', learning_rate_init = .01)

targetsclass1 = np.ones((np.shape(class1)[0],1))

targetsclass2 = -np.ones((np.shape(class2)[0],1))



targets = np.vstack((targetsclass1, targetsclass2))


data = np.vstack((class1, class2))

classifier.fit(data, targets)

x1min = np.min(data[:,0]) 
x1max = np.max(data[:,0])

x2min = np.min(data[:,1])
x2max = np.max(data[:,1])


x1GridSide = np.linspace(x1min, x1max, 100)
x2GridSide = np.linspace(x2min, x2max, 100)

x1grid, x2grid = np.meshgrid(x1GridSide, x2GridSide)


grid_data = np.hstack((x1grid.flatten().reshape(-1,1), x2grid.flatten().reshape(-1,1)))

predicted_targets = classifier.predict(grid_data)
# Out:
# /Users/aishahodzic/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
from matplotlib.colors import ListedColormap
cm = plt.cm.RdBu
cm_bright = ListedColormap(['#0000FF', '#FF0000'])


plt.contourf(x1grid,x2grid, np.reshape(predicted_targets,np.shape(x1grid)), cmap = cm_bright, alpha=0.1)


plt.scatter(class1[:,0],class1[:,1], c='r')
plt.scatter(class2[:,0],class2[:,1], c='b')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier

import scipy.io
class1b = scipy.io.loadmat('MLPdata1b.mat')['MLPdata1b']
class2b = scipy.io.loadmat('MLPdata2b.mat')['MLPdata2b']

plt.scatter(class1b[:,0],class1b[:,1], c='r')
plt.scatter(class2b[:,0],class2b[:,1], c='b')
plt.show()



from sklearn.neural_network import MLPClassifier

classifierb = MLPClassifier(hidden_layer_sizes =(110,125), activation = 'logistic', solver='lbfgs', learning_rate_init = .01)
print(np.shape(class1b))
print(np.shape(class2b))

targetsclass1b = np.ones((np.shape(class1b)[0],1))
targetsclass2b = -np.ones((np.shape(class2b)[0],1))

targetsb = np.vstack((targetsclass1b, targetsclass2b))

datab = np.vstack((class1b, class2b))

classifierb.fit(datab, targetsb)

x1minb = np.min(datab[:,0]) 
x1maxb = np.max(datab[:,0])
x2minb = np.min(datab[:,1])
x2maxb = np.max(datab[:,1])
x1GridSideb = np.linspace(x1minb, x1maxb, 100)
x2GridSideb = np.linspace(x2minb, x2maxb, 100)


x1gridb, x2gridb = np.meshgrid(x1GridSideb, x2GridSideb)
grid_datab = np.hstack((x1gridb.flatten().reshape(-1,1), x2gridb.flatten().reshape(-1,1))) 

predicted_targetsb = classifierb.predict(grid_datab)




from matplotlib.colors import ListedColormap
cm = plt.cm.RdBu
cm_bright = ListedColormap(['#0000FF', '#FF0000'])

plt.contourf(x1gridb,x2gridb, np.reshape(predicted_targetsb,np.shape(x1gridb)), cmap = cm_bright, alpha=0.1)

plt.scatter(class1b[:,0],class1b[:,1], c='r')
plt.scatter(class2b[:,0],class2b[:,1], c='b')
plt.show()
# Out:
# (134, 2)
# (332, 2)
# /Users/aishahodzic/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
from matplotlib.colors import ListedColormap
cm = plt.cm.RdBu
cm_bright = ListedColormap(['#0000FF', '#FF0000'])

plt.contourf(x1gridb,x2gridb, np.reshape(predicted_targetsb,np.shape(x1gridb)), cmap = cm_bright, alpha=0.1)
plt.scatter(class1b[:,0],class1b[:,1], c='r')
plt.scatter(class2b[:,0],class2b[:,1], c='b')
plt.show()
